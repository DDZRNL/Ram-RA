# %%
import tabula as tb
import pandas as pd
import PyPDF2
from PyPDF2 import PdfReader
import re
import docx
from docx import Document
import zipfile
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup
import os
import pandas as pd
import csv
import json
import re

# %%
def filterHTMLstr(str):
    html_tag = {'&#xA;': '\n', '&quot;': '\"', '&amp;': '', '&lt;': '<', '&gt;': '>',
                '&apos;': "'", '&nbsp;': ' ', '&yen;': '¥', '&copy;': '©', '&divide;': '÷'
        , '&times;': 'x', '&trade;': '™', '&reg;': '®', '&sect;': '§', '&euro;': '€',
                '&pound;': '£', '&cent;': '￠', '&raquo;': '»', '&nbsp': ' ', u'\xa0': ' ',
                '\n': ' ', '\t': ' ', '    ': '', '&emsp': ' ', ' ,':',', '  ':' '
                }
    for k, v in html_tag.items():
        str = str.replace(k, v)
        # str = str.replace(k[1:], v)
    str = " ".join(str.split())
    str = str.strip('\n')
    str = str.strip(' ')
    return str

def MultipleFileProcess(files_position):
    totaldata = []
    for position in files_position:
        data = SingleHTMLProcess(position)
        totaldata.append(data)

    return totaldata

def to_CSV(totaldata):
    pd.DataFrame(totaldata).to_csv('./result/2011.csv', index=False, encoding="utf-8")

# %%
### code entry
path = "./data/2011.html"
htmlfile = open(path, 'r', encoding='utf-8')
html=htmlfile  
bs = BeautifulSoup(html, "lxml")  # 缩进格式
totaldata = handle(bs)
to_CSV(totaldata)
# Out:
# higher level topic name: Space Operations
# topic name: Topic O1 Space Communications
# subtopic name: O1.01Antenna Technology
# subtopic name: O1.02Reconfigurable/Reprogrammable Communication Systems
# subtopic name: O1.03Game Changing Technologies
# subtopic name: O1.04Long Range Optical Telecommunications
# subtopic name: O1.05Long Range Space RF Telecommunications
# subtopic name: O1.06CoNNeCT Experiments
# topic name: Topic O2 Space Transportation
# subtopic name: O2.01Nano/Small Sat Launch Vehicle Technology
# subtopic name: O2.02Propulsion Technologies
# subtopic name: O2.0321st Century Spaceport Ground Systems Technologies
# subtopic name: O2.04Advanced Tank Technology Development
# subtopic name: O2.05Advanced Propulsion Testing Technologies
# topic name: Topic O3 Processing and Operations
# subtopic name: O3.01Remotely Operated Mobile Sensing Technologies for inside ISS
# subtopic name: O3.02ISS Utilization
# subtopic name: O3.03ISS Demonstration & Development of Improved Exploration Technologies
# subtopic name: O3.04Vehicle Integration and Ground Processing
# subtopic name: O3.05Advanced Motion Imaging
# subtopic name: O3.06Environmental Control Systems & Technologies for NR & Cubesats
# topic name: Topic O4 Navigation
# subtopic name: O4.01Metric Tracking of Launch Vehicles
# subtopic name: O4.02PNT (Positioning, Navigation, and Timing) Sensors and Components
# subtopic name: O4.03Flight Dynamics Technologies and Software
# higher level topic name: Aeronautics Research
# topic name: Topic A1 Aviation Safety
# subtopic name: A1.01Aviation External Hazard Sensor Technologies
# subtopic name: A1.02Inflight Icing Hazard Mitigation Technology
# subtopic name: A1.03Durable Propulsion Components
# subtopic name: A1.04Airframe Design and Sustainment
# subtopic name: A1.05Sensing and Diagnostic Capabilities for Degradation in Aircraft Materials and Structures
# subtopic name: A1.06Propulsion Health State Assessment and Management
# subtopic name: A1.07Avionics Health State Assessment and Management
# subtopic name: A1.08Crew Systems Technologies for Improved Aviation Safety
# subtopic name: A1.09Integrated Vehicle Dynamics Modeling Methods for LOC Conditions
# subtopic name: A1.10Advanced Dynamic Testing Capability for Abnormal Flight Conditions
# subtopic name: A1.11Transport Aircraft Simulator Motion Fidelity For Abnormal Flight Conditions
# subtopic name: A1.12Propulsion System Performance Prediction for Integrated Flight and Propulsion Control
# subtopic name: A1.13Advanced Upset Protection System
# subtopic name: A1.14Detection, Identification, and Mitigation of Sensor Failures
# subtopic name: A1.15Unmanned Vehicle Design for Loss-of-Control Flight Research
# subtopic name: A1.16Validation Methods for Safety-Critical Systems Operating under LOC Conditions
# subtopic name: A1.17Data Mining and Knowledge Discovery
# subtopic name: A1.18Prognostics and Decision Making
# subtopic name: A1.19Technologies for Improved Design and Analysis of Safety-Critical Dynamic Systems
# subtopic name: A1.20Verification and Validation of Flight-Critical Systems
# topic name: Topic A2 Fundamental Aeronautics
# subtopic name: A2.01Materials and Structures for Future Aircraft
# subtopic name: A2.02Combustion for Aerospace Vehicles
# subtopic name: A2.03Aero-Acoustics
# subtopic name: A2.04Aeroelasticity
# subtopic name: A2.05Aerodynamics
# subtopic name: A2.06Aerothermodynamics
# subtopic name: A2.07Flight and Propulsion Control and Dynamics
# subtopic name: A2.08Aircraft Systems Analysis, Design and Optimization
# subtopic name: A2.09Rotorcraft
# subtopic name: A2.10Propulsion Systems
# topic name: Topic A3 Airspace Systems
# subtopic name: A3.01Concepts and Technology Development (CTD)
# subtopic name: A3.02Systems Analysis Integration Evaluation (SAIE)
# topic name: Topic A4 Aeronautics Test Technologies
# subtopic name: A4.01Ground Test Techniques and Measurement Technology
# subtopic name: A4.02Flight Test Techniques and Measurement Technology
# topic name: Topic A5 Integrated System Research Project (ISRP)
# subtopic name: A5.01UAS Integration in the NAS
# higher level topic name: Science
# topic name: Topic S1 Sensors, Detectors and Instruments
# subtopic name: S1.01Lidar and Laser System Components
# subtopic name: S1.02Active Microwave Technologies
# subtopic name: S1.03Passive Microwave Technologies
# subtopic name: S1.04Sensor and Detector Technology for Visible, IR, Far IR and Submillimeter
# subtopic name: S1.05Detector Technologies for UV, X-Ray, Gamma-Ray and Cosmic-Ray Instruments
# subtopic name: S1.06Particles and Field Sensors and Instrument Enabling Technologies
# subtopic name: S1.07Cryogenic Systems for Sensors and Detectors
# subtopic name: S1.08In Situ Airborne, Surface, and Submersible Instruments for Earth Science
# subtopic name: S1.09In Situ Sensors and Sensor Systems for Lunar and Planetary Science
# subtopic name: S1.10Atomic Interferometry
# subtopic name: S1.11Planetary Orbital Sensors and Sensor Systems (POSSS)
# topic name: Topic S2 Advanced Telescope Systems
# subtopic name: S2.01Precision Spacecraft Formations for Telescope Systems
# subtopic name: S2.02Proximity Glare Suppression for Astronomical Coronagraphy
# subtopic name: S2.03Precision Deployable Optical Structures and Metrology
# subtopic name: S2.04Advanced Optical Component Systems
# subtopic name: S2.05Optics Manufacturing and Metrology for Telescope Optical Surfaces
# topic name: Topic S3 Spacecraft and Platform Subsystems
# subtopic name: S3.01Command, Data Handling, and Electronics
# subtopic name: S3.02Thermal Control Systems
# subtopic name: S3.03Power Generation and Conversion
# subtopic name: S3.04Propulsion Systems
# subtopic name: S3.05Power Electronics and Management, and Energy Storage
# subtopic name: S3.06Guidance, Navigation and Control
# subtopic name: S3.07Terrestrial and Planetary Balloons
# subtopic name: S3.08Unmanned Aircraft and Sounding Rocket Technologies
# topic name: Topic S4 Low-Cost Small Spacecraft and Technologies
# subtopic name: S4.01Unique Mission Architectures Using Small Spacecraft
# topic name: Topic S5 Robotic Exploration Technologies
# subtopic name: S5.01Planetary Entry, Descent and Landing Technology
# subtopic name: S5.02Sample Collection, Processing, and Handling
# subtopic name: S5.03Surface and Subsurface Robotic Exploration
# subtopic name: S5.04Spacecraft Technology for Sample Return Missions
# subtopic name: S5.05Extreme Environments Technology
# subtopic name: S5.06Planetary Protection
# topic name: Topic S6 Information Technologies
# subtopic name: S6.01Technologies for Large-Scale Numerical Simulation
# subtopic name: S6.02Earth Science Applied Research and Decision Support
# subtopic name: S6.03Algorithms and Tools for Science Data Processing, Discovery and Analysis, in State-of-the-Art Data Environments
# subtopic name: S6.04Integrated Mission Modeling for Opto-mechanical Systems
# subtopic name: S6.05Fault Management Technologies
# higher level topic name: Exploration Systems
# topic name: Topic X1 In Situ Resource Utilization
# subtopic name: X1.01In-Situ Resource Characterization, Extraction, Transfer, and Processing
# topic name: Topic X2 Propulsion
# subtopic name: X2.01Low Cost Heavy Lift Propulsion
# subtopic name: X2.02High Thrust In-Space Propulsion
# subtopic name: X2.03Electric Propulsion Systems
# topic name: Topic X3 Life Support and Habitation Systems
# subtopic name: X3.01Enabling Technologies for Biological Life Support
# subtopic name: X3.02Crew Accommodations and Waste Processing for Long Duration Missions
# subtopic name: X3.03Environmental Monitoring and Fire Protection for Spacecraft Autonomy
# subtopic name: X3.04Spacecraft Cabin Ventilation and Thermal Control
# topic name: Topic X4 Extra-Vehicular Activity Technology
# subtopic name: X4.01Space Suit Pressure Garment and Airlock Technologies
# subtopic name: X4.02Space Suit Life Support Systems
# subtopic name: X4.03Space Suit Radio, Sensors, Displays, Cameras, and Audio
# topic name: Topic X5 Lightweight Spacecraft Materials and Structures
# subtopic name: X5.01Expandable Structures
# subtopic name: X5.02Advanced Fabrication and Manufacturing of Metallic and Polymer Matrix Composite Materials for Lightweight Structures
# subtopic name: X5.03Spaceflight Structural Sensor Systems and NDE
# topic name: Topic X6 Autonomous Systems and Avionics
# subtopic name: X6.01Spacecraft Autonomy and Space Mission Automation
# subtopic name: X6.02Radiation Hardened/Tolerant and Low Temperature Electronics and Processors
# subtopic name: X6.03Integrated System Health Management for Flexible Exploration
# topic name: Topic X7 Human-Robotic Systems
# subtopic name: X7.01Human Robotic Systems - Human Robot Interfaces
# subtopic name: X7.02Human-Robotic Systems - Mobility Subsystems
# topic name: Topic X8 High-Efficiency Space Power Systems
# subtopic name: X8.01Fuel Cells and Electrolyzers
# subtopic name: X8.02Space-Rated Batteries
# subtopic name: X8.03Space Nuclear Power Systems
# subtopic name: X8.04Advanced Photovoltaic Systems
# topic name: Topic X9 Entry, Descent, and Landing (EDL) Technology
# subtopic name: X9.01Ablative Thermal Protection Systems
# subtopic name: X9.02Advanced Integrated Hypersonic Entry Systems
# topic name: Topic X10 Cryogenic Propellant Storage and Transfer
# subtopic name: X10.01Cryogenic Fluid Management Technologies
# topic name: Topic X11 Radiation Protection
# subtopic name: X11.01Radiation Shielding Materials Systems
# subtopic name: X11.02Integrated Advanced Alert/Warning Systems for Solar Proton Events
# topic name: Topic X12 Exploration Crew Health Capabilities
# subtopic name: X12.01Crew Exercise Systems
# subtopic name: X12.02Portable Load Sensing Systems
# topic name: Topic X13 Exploration Medical Capability
# subtopic name: X13.01Smart Phone Driven Blood-Based Diagnostics
# subtopic name: X13.02Non-Wet Prep Electrodes
# topic name: Topic X14 Behavioral Health and Performance
# subtopic name: X14.01Virtual Reality and World Technologies for Team Training Approaches
# topic name: Topic X15 Space Human Factors and Food Systems
# subtopic name: X15.01A New Technique for Automated Analyses of Raw Operational Videos
# subtopic name: X15.02Advanced Food Technologies
# topic name: Topic X16 Space Radiation
# subtopic name: X16.01Radiation Measurement Technologies
# topic name: Topic X17 Inflight Biological Sample Preservation and Analysis
# subtopic name: X17.01Alternative Methods for Ambient Preservation of Human Biological Samples During Extended Spaceflight and Planetary Operations

# %%
def handle(bs):
    totalData = []
    ### get overall topic
    regEvens = re.compile('md-taxonomy even.*')
    regOdds = re.compile('md-taxonomy odd.*')
    evens = bs.find_all("li", {"class": regEvens})
    odds = bs.find_all("li", {"class": regOdds})
    offset = 0
    for index in range(4):
        dic = {}
        higher_topic_block = evens[int(index / 2) + offset] if int(index % 2) == 0 else odds[int(index / 2) + offset]
        dic["Higher Topic"] = getHigherTopicName(higher_topic_block)
        regTopicEvens = re.compile('first-topic even.*')
        regTopicOdds = re.compile('first-topic odd.*')
        topic_even = higher_topic_block.find_all("li", {"class": regTopicEvens})
        topic_odd = higher_topic_block.find_all("li", {"class": regTopicOdds})
        for index2 in range(len(topic_even) + len(topic_odd)):
                topic_block = topic_even[int(index2 / 2)] if int(index2 % 2) == 0 else topic_odd[int(index2 / 2)]
                dic["Focus Area"] = getTopicName(topic_block)
                subtopic_even = topic_block.find_all("li", {"class": "second-topic even"})
                subtopic_odd = topic_block.find_all("li", {"class": "second-topic odd"})
                for index3 in range(len(subtopic_even) + len(subtopic_odd)):
                    subtopic_block = subtopic_even[int(index3 / 2)] if int(index3 % 2) == 0 else subtopic_odd[int(index3 / 2)]
                    dic["Subtopic"] = getSubtopicName(subtopic_block)
                    metaDic = getMetaData(subtopic_block)
                    for k in metaDic:
                        dic[k] = metaDic[k]
                    ### get other data
                    whole_info_block = subtopic_block.find("div", {"class": "whole-topic-content"})
                    new_dic = dic.copy()
                    new_dic["Content"] = filterHTMLstr(whole_info_block.get_text()) if whole_info_block != None else ""
                    totalData.append(new_dic)
    return totalData

# %%
### get higher level topic
def getHigherTopicName(topic_block):
    higher_topic_name = filterHTMLstr(topic_block.find("h2").get_text())
    print("higher level topic name:", higher_topic_name)  # higher level topic name
    return higher_topic_name

### get topic name
def getTopicName(topic_block):
    topic_name = filterHTMLstr(topic_block.find("h4", {"class": "topicTitle"}).get_text()).replace("PDF", "")
    print("topic name:", topic_name)  # subtopic name
    return topic_name

### handle every sub-topic
def getSubtopicName(subtopic_block):
    subtopic_name = filterHTMLstr(subtopic_block.find("p", {"class": "subtopic"}).get_text())
    print("subtopic name:", subtopic_name)  # subtopic name
    return subtopic_name

# %%
### get Lead Center, Participating Center(s), Solicitation Year
def getMetaData(subtopic_block):
    dic = {}
    info_group = subtopic_block.find_all("p", {"class": "l-center"})
    for raw_info in info_group:
        info = filterHTMLstr(raw_info.get_text())
        pair = info.split(":")
        dic[pair[0]] = pair[1]
        # print(pair[0], pair[1])
    # print(dic)
    return dic

# %%
for i in evens:
    getHigherTopicName(i)
# Out:
# higher level topic name: Aeronautics Research
# higher level topic name: Science
# higher level topic name: TA1 Launch Propulsion Systems
# higher level topic name: TA3 Space Power and Energy Storage
# higher level topic name: TA5 Communication and Navigation
# higher level topic name: TA7 Human Exploration Destination Systems
# higher level topic name: TA9 Entry, Descent and Landing Systems
# higher level topic name: TA10.2 Energy Generation and Storage
# higher level topic name: TA12 Materials, Structures, Mechanical Systems and Manufacturing
# higher level topic name: TA14 Thermal Management Systems

# %%
for i in odds:
    getHigherTopicName(i)
# Out:
# higher level topic name: Human Exploration and Operations
# higher level topic name: Space Technology
# higher level topic name: TA2 In-Space Propulsion Technologies
# higher level topic name: TA4 Robotics, Telerobotics and Autonomous Systems
# higher level topic name: TA6 Human Health, Life Support and Habitation Systems
# higher level topic name: TA8 Science Instruments, Observatories & Sensor Systems
# higher level topic name: TA10 Nanotechnology
# higher level topic name: TA11 Modeling, Simulation, Information Technology and Processing
# higher level topic name: TA13 Ground and Launch Systems Processing
# higher level topic name: TA15 Aeronautics

# %%
regEvens = re.compile('md-taxonomy even.*')
regOdds = re.compile('md-taxonomy odd.*')
evens = bs.find_all("li", {"class": regEvens})
odds = bs.find_all("li", {"class": regOdds})
offset = 0
for index in range(4):
    higher_topic_block = evens[int(index / 2) + offset] if int(index % 2) == 0 else odds[int(index / 2) + offset]
    getHigherTopicName(higher_topic_block)
    regTopicEvens = re.compile('first-topic even.*')
    regTopicOdds = re.compile('first-topic odd.*')
    topic_even = higher_topic_block.find_all("li", {"class": regTopicEvens})
    topic_odd = higher_topic_block.find_all("li", {"class": regTopicOdds})
    for index2 in range(len(topic_even) + len(topic_odd)):
            topic_block = topic_even[int(index2 / 2)] if int(index2 % 2) == 0 else topic_odd[int(index2 / 2)]
            getTopicName(topic_block)
            subtopic_even = topic_block.find_all("li", {"class": "second-topic even"})
            subtopic_odd = topic_block.find_all("li", {"class": "second-topic odd"})
            for index3 in range(len(subtopic_even) + len(subtopic_odd)):
                subtopic_block = subtopic_even[int(index3 / 2)] if int(index3 % 2) == 0 else subtopic_odd[int(index3 / 2)]
                getSubtopicName(subtopic_block)
# Out:
# higher level topic name: Space Operations
# topic name: Topic O1 Space Communications
# subtopic name: O1.01Antenna Technology
# subtopic name: O1.02Reconfigurable/Reprogrammable Communication Systems
# subtopic name: O1.03Game Changing Technologies
# subtopic name: O1.04Long Range Optical Telecommunications
# subtopic name: O1.05Long Range Space RF Telecommunications
# subtopic name: O1.06CoNNeCT Experiments
# topic name: Topic O2 Space Transportation
# subtopic name: O2.01Nano/Small Sat Launch Vehicle Technology
# subtopic name: O2.02Propulsion Technologies
# subtopic name: O2.0321st Century Spaceport Ground Systems Technologies
# subtopic name: O2.04Advanced Tank Technology Development
# subtopic name: O2.05Advanced Propulsion Testing Technologies
# topic name: Topic O3 Processing and Operations
# subtopic name: O3.01Remotely Operated Mobile Sensing Technologies for inside ISS
# subtopic name: O3.02ISS Utilization
# subtopic name: O3.03ISS Demonstration & Development of Improved Exploration Technologies
# subtopic name: O3.04Vehicle Integration and Ground Processing
# subtopic name: O3.05Advanced Motion Imaging
# subtopic name: O3.06Environmental Control Systems & Technologies for NR & Cubesats
# topic name: Topic O4 Navigation
# subtopic name: O4.01Metric Tracking of Launch Vehicles
# subtopic name: O4.02PNT (Positioning, Navigation, and Timing) Sensors and Components
# subtopic name: O4.03Flight Dynamics Technologies and Software
# higher level topic name: Aeronautics Research
# topic name: Topic A1 Aviation Safety
# subtopic name: A1.01Aviation External Hazard Sensor Technologies
# subtopic name: A1.02Inflight Icing Hazard Mitigation Technology
# subtopic name: A1.03Durable Propulsion Components
# subtopic name: A1.04Airframe Design and Sustainment
# subtopic name: A1.05Sensing and Diagnostic Capabilities for Degradation in Aircraft Materials and Structures
# subtopic name: A1.06Propulsion Health State Assessment and Management
# subtopic name: A1.07Avionics Health State Assessment and Management
# subtopic name: A1.08Crew Systems Technologies for Improved Aviation Safety
# subtopic name: A1.09Integrated Vehicle Dynamics Modeling Methods for LOC Conditions
# subtopic name: A1.10Advanced Dynamic Testing Capability for Abnormal Flight Conditions
# subtopic name: A1.11Transport Aircraft Simulator Motion Fidelity For Abnormal Flight Conditions
# subtopic name: A1.12Propulsion System Performance Prediction for Integrated Flight and Propulsion Control
# subtopic name: A1.13Advanced Upset Protection System
# subtopic name: A1.14Detection, Identification, and Mitigation of Sensor Failures
# subtopic name: A1.15Unmanned Vehicle Design for Loss-of-Control Flight Research
# subtopic name: A1.16Validation Methods for Safety-Critical Systems Operating under LOC Conditions
# subtopic name: A1.17Data Mining and Knowledge Discovery
# subtopic name: A1.18Prognostics and Decision Making
# subtopic name: A1.19Technologies for Improved Design and Analysis of Safety-Critical Dynamic Systems
# subtopic name: A1.20Verification and Validation of Flight-Critical Systems
# topic name: Topic A2 Fundamental Aeronautics
# subtopic name: A2.01Materials and Structures for Future Aircraft
# subtopic name: A2.02Combustion for Aerospace Vehicles
# subtopic name: A2.03Aero-Acoustics
# subtopic name: A2.04Aeroelasticity
# subtopic name: A2.05Aerodynamics
# subtopic name: A2.06Aerothermodynamics
# subtopic name: A2.07Flight and Propulsion Control and Dynamics
# subtopic name: A2.08Aircraft Systems Analysis, Design and Optimization
# subtopic name: A2.09Rotorcraft
# subtopic name: A2.10Propulsion Systems
# topic name: Topic A3 Airspace Systems
# subtopic name: A3.01Concepts and Technology Development (CTD)
# subtopic name: A3.02Systems Analysis Integration Evaluation (SAIE)
# topic name: Topic A4 Aeronautics Test Technologies
# subtopic name: A4.01Ground Test Techniques and Measurement Technology
# subtopic name: A4.02Flight Test Techniques and Measurement Technology
# topic name: Topic A5 Integrated System Research Project (ISRP)
# subtopic name: A5.01UAS Integration in the NAS
# higher level topic name: Science
# topic name: Topic S1 Sensors, Detectors and Instruments
# subtopic name: S1.01Lidar and Laser System Components
# subtopic name: S1.02Active Microwave Technologies
# subtopic name: S1.03Passive Microwave Technologies
# subtopic name: S1.04Sensor and Detector Technology for Visible, IR, Far IR and Submillimeter
# subtopic name: S1.05Detector Technologies for UV, X-Ray, Gamma-Ray and Cosmic-Ray Instruments
# subtopic name: S1.06Particles and Field Sensors and Instrument Enabling Technologies
# subtopic name: S1.07Cryogenic Systems for Sensors and Detectors
# subtopic name: S1.08In Situ Airborne, Surface, and Submersible Instruments for Earth Science
# subtopic name: S1.09In Situ Sensors and Sensor Systems for Lunar and Planetary Science
# subtopic name: S1.10Atomic Interferometry
# subtopic name: S1.11Planetary Orbital Sensors and Sensor Systems (POSSS)
# topic name: Topic S2 Advanced Telescope Systems
# subtopic name: S2.01Precision Spacecraft Formations for Telescope Systems
# subtopic name: S2.02Proximity Glare Suppression for Astronomical Coronagraphy
# subtopic name: S2.03Precision Deployable Optical Structures and Metrology
# subtopic name: S2.04Advanced Optical Component Systems
# subtopic name: S2.05Optics Manufacturing and Metrology for Telescope Optical Surfaces
# topic name: Topic S3 Spacecraft and Platform Subsystems
# subtopic name: S3.01Command, Data Handling, and Electronics
# subtopic name: S3.02Thermal Control Systems
# subtopic name: S3.03Power Generation and Conversion
# subtopic name: S3.04Propulsion Systems
# subtopic name: S3.05Power Electronics and Management, and Energy Storage
# subtopic name: S3.06Guidance, Navigation and Control
# subtopic name: S3.07Terrestrial and Planetary Balloons
# subtopic name: S3.08Unmanned Aircraft and Sounding Rocket Technologies
# topic name: Topic S4 Low-Cost Small Spacecraft and Technologies
# subtopic name: S4.01Unique Mission Architectures Using Small Spacecraft
# topic name: Topic S5 Robotic Exploration Technologies
# subtopic name: S5.01Planetary Entry, Descent and Landing Technology
# subtopic name: S5.02Sample Collection, Processing, and Handling
# subtopic name: S5.03Surface and Subsurface Robotic Exploration
# subtopic name: S5.04Spacecraft Technology for Sample Return Missions
# subtopic name: S5.05Extreme Environments Technology
# subtopic name: S5.06Planetary Protection
# topic name: Topic S6 Information Technologies
# subtopic name: S6.01Technologies for Large-Scale Numerical Simulation
# subtopic name: S6.02Earth Science Applied Research and Decision Support
# subtopic name: S6.03Algorithms and Tools for Science Data Processing, Discovery and Analysis, in State-of-the-Art Data Environments
# subtopic name: S6.04Integrated Mission Modeling for Opto-mechanical Systems
# subtopic name: S6.05Fault Management Technologies
# higher level topic name: Exploration Systems
# topic name: Topic X1 In Situ Resource Utilization
# subtopic name: X1.01In-Situ Resource Characterization, Extraction, Transfer, and Processing
# topic name: Topic X2 Propulsion
# subtopic name: X2.01Low Cost Heavy Lift Propulsion
# subtopic name: X2.02High Thrust In-Space Propulsion
# subtopic name: X2.03Electric Propulsion Systems
# topic name: Topic X3 Life Support and Habitation Systems
# subtopic name: X3.01Enabling Technologies for Biological Life Support
# subtopic name: X3.02Crew Accommodations and Waste Processing for Long Duration Missions
# subtopic name: X3.03Environmental Monitoring and Fire Protection for Spacecraft Autonomy
# subtopic name: X3.04Spacecraft Cabin Ventilation and Thermal Control
# topic name: Topic X4 Extra-Vehicular Activity Technology
# subtopic name: X4.01Space Suit Pressure Garment and Airlock Technologies
# subtopic name: X4.02Space Suit Life Support Systems
# subtopic name: X4.03Space Suit Radio, Sensors, Displays, Cameras, and Audio
# topic name: Topic X5 Lightweight Spacecraft Materials and Structures
# subtopic name: X5.01Expandable Structures
# subtopic name: X5.02Advanced Fabrication and Manufacturing of Metallic and Polymer Matrix Composite Materials for Lightweight Structures
# subtopic name: X5.03Spaceflight Structural Sensor Systems and NDE
# topic name: Topic X6 Autonomous Systems and Avionics
# subtopic name: X6.01Spacecraft Autonomy and Space Mission Automation
# subtopic name: X6.02Radiation Hardened/Tolerant and Low Temperature Electronics and Processors
# subtopic name: X6.03Integrated System Health Management for Flexible Exploration
# topic name: Topic X7 Human-Robotic Systems
# subtopic name: X7.01Human Robotic Systems - Human Robot Interfaces
# subtopic name: X7.02Human-Robotic Systems - Mobility Subsystems
# topic name: Topic X8 High-Efficiency Space Power Systems
# subtopic name: X8.01Fuel Cells and Electrolyzers
# subtopic name: X8.02Space-Rated Batteries
# subtopic name: X8.03Space Nuclear Power Systems
# subtopic name: X8.04Advanced Photovoltaic Systems
# topic name: Topic X9 Entry, Descent, and Landing (EDL) Technology
# subtopic name: X9.01Ablative Thermal Protection Systems
# subtopic name: X9.02Advanced Integrated Hypersonic Entry Systems
# topic name: Topic X10 Cryogenic Propellant Storage and Transfer
# subtopic name: X10.01Cryogenic Fluid Management Technologies
# topic name: Topic X11 Radiation Protection
# subtopic name: X11.01Radiation Shielding Materials Systems
# subtopic name: X11.02Integrated Advanced Alert/Warning Systems for Solar Proton Events
# topic name: Topic X12 Exploration Crew Health Capabilities
# subtopic name: X12.01Crew Exercise Systems
# subtopic name: X12.02Portable Load Sensing Systems
# topic name: Topic X13 Exploration Medical Capability
# subtopic name: X13.01Smart Phone Driven Blood-Based Diagnostics
# subtopic name: X13.02Non-Wet Prep Electrodes
# topic name: Topic X14 Behavioral Health and Performance
# subtopic name: X14.01Virtual Reality and World Technologies for Team Training Approaches
# topic name: Topic X15 Space Human Factors and Food Systems
# subtopic name: X15.01A New Technique for Automated Analyses of Raw Operational Videos
# subtopic name: X15.02Advanced Food Technologies
# topic name: Topic X16 Space Radiation
# subtopic name: X16.01Radiation Measurement Technologies
# topic name: Topic X17 Inflight Biological Sample Preservation and Analysis
# subtopic name: X17.01Alternative Methods for Ambient Preservation of Human Biological Samples During Extended Spaceflight and Planetary Operations
