# %%
import tabula as tb
import pandas as pd
import PyPDF2
from PyPDF2 import PdfReader
import re
import docx
from docx import Document
import zipfile
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup
import os
import pandas as pd
import csv
import json
import re

# %%
def filterHTMLstr(str):
    html_tag = {'&#xA;': '\n', '&quot;': '\"', '&amp;': '', '&lt;': '<', '&gt;': '>',
                '&apos;': "'", '&nbsp;': ' ', '&yen;': '¥', '&copy;': '©', '&divide;': '÷'
        , '&times;': 'x', '&trade;': '™', '&reg;': '®', '&sect;': '§', '&euro;': '€',
                '&pound;': '£', '&cent;': '￠', '&raquo;': '»', '&nbsp': ' ', u'\xa0': ' ',
                '\n': ' ', '\t': ' ', '    ': '', '&emsp': ' ', ' ,':',', '  ':' '
                }
    for k, v in html_tag.items():
        str = str.replace(k, v)
        # str = str.replace(k[1:], v)
    str = " ".join(str.split())
    str = str.strip('\n')
    str = str.strip(' ')
    return str

def MultipleFileProcess(files_position):
    totaldata = []
    for position in files_position:
        data = SingleHTMLProcess(position)
        totaldata.append(data)

    return totaldata

def to_CSV(totaldata):
    pd.DataFrame(totaldata).to_csv('./result/2014.csv', index=False, encoding="utf-8")

# %%
### code entry
path = "./data/2014.html"
htmlfile = open(path, 'r', encoding='utf-8')
html=htmlfile  
bs = BeautifulSoup(html, "lxml")  # 缩进格式
totaldata = handle(bs)
to_CSV(totaldata)
# Out:
# higher level topic name: TA1 Launch Propulsion Systems
# topic name: TA1.3 Air Breathing Propulsion Systems
# subtopic name: A3.03Low Emissions/Clean Power
# higher level topic name: TA2 In-Space Propulsion Technologies
# topic name: TA2.1 Chemical Propulsion
# subtopic name: H2.02In-Space Chemical Propulsion
# subtopic name: S4.03Spacecraft Technology for Sample Return Missions
# topic name: TA2.2 Non-Chemical Propulsion
# subtopic name: Z1.03Integrated Nuclear Power & Propulsion
# subtopic name: H2.01High Power Electric Propulsion
# subtopic name: H2.03Nuclear Thermal Propulsion (NTP)
# subtopic name: S3.02Propulsion Systems for Robotic Science Missions
# topic name: TA2.4 Supporting Technologies
# subtopic name: H2.04Nuclear Thermal Propulsion (NTP) Ground Test Technologies
# higher level topic name: TA3 Space Power and Energy Storage
# topic name: TA3.1 Power Generation
# subtopic name: Z1.01Advanced Photovoltaic Systems
# subtopic name: H8.02Space Nuclear Power Systems
# topic name: TA3.2 Energy Storage
# subtopic name: Z1.02Advanced Space Battery Technology
# topic name: TA3.3 Power Management and Distribution
# subtopic name: S3.03Power Electronics and Management, and Energy Storage
# topic name: TA3.4 Cross Cutting Technology
# subtopic name: H8.01Solid Oxide Fuel Cells and Electrolyzers
# subtopic name: S3.01Power Generation and Conversion
# subtopic name: S3.06Terrestrial and Planetary Balloons
# higher level topic name: TA4 Robotics, Telerobotics and Autonomous Systems
# topic name: TA4.3 Manipulation
# subtopic name: S4.02Robotic Mobility, Manipulation and Sampling
# topic name: TA4.5 Autonomy
# subtopic name: A1.03Real-Time Safety Assurance under Unanticipated and Hazardous Conditions
# subtopic name: H6.01Spacecraft Autonomy and Space Mission Automation
# higher level topic name: TA5 Communication and Navigation
# topic name: TA5.1 Optical Comm. And Navigation
# subtopic name: H9.02Long Range Optical Telecommunications
# subtopic name: H9.05Advanced Celestial Navigation Techniques and Systems for Deep-Space Applications
# topic name: TA5.2 Radio Frequency Communications
# subtopic name: H9.01SCaN Testbed (CoNNeCT) Experiments
# subtopic name: H9.03Long Range Space RF Telecommunications
# topic name: TA5.4 Position, Navigation, and Timing
# subtopic name: H9.04Flight Dynamics GNC Technologies and Software
# subtopic name: S3.05Guidance, Navigation and Control
# higher level topic name: TA6 Human Health, Life Support and Habitation Systems
# topic name: TA6.1 Environmental Control Life Support & Habitation Systems
# subtopic name: H3.03Human Accommodations and Habitation Systems for Future Exploration Missions
# subtopic name: H3.04Development of Treatment Technologies and Process Monitoring for Water Recovery
# topic name: TA6.2 Extravehicular Activity Systems
# subtopic name: H4.01Space Suit Pressure Garment and Airlock Technologies
# topic name: TA6.3 Human Health and Performance
# subtopic name: H12.01Next Generation Oxygen Concentrator for Medical Scenarios
# subtopic name: H12.02Inflight Calcium Isotope Measurement Device
# subtopic name: H12.03Objective Sleep Measures for Spaceflight Operations
# subtopic name: H12.04Advanced Food Technology
# topic name: TA6.5 Radiation
# subtopic name: H11.01Radiation Shielding Systems
# higher level topic name: TA7 Human Exploration Destination Systems
# topic name: TA7.1 In-Situ Resource Utilization
# subtopic name: H1.01In-Situ Resource Utilization - Mars Atmosphere/Gas Chemical Processing
# subtopic name: H10.02International Space Station (ISS) Utilization
# topic name: TA7.4 Advanced Habitat Systems
# subtopic name: H3.02Atmosphere Revitalization and Fire Recovery for Future Exploration Missions
# higher level topic name: TA8 Science Instruments, Observatories & Sensor Systems
# topic name: TA8.1 Science Instruments
# subtopic name: S1.06In Situ Sensors and Sensor Systems for Lunar and Planetary Science
# subtopic name: S1.07Airborne Measurement Systems
# subtopic name: S1.08Surface and Sub-surface Measurement Systems
# subtopic name: S2.01Proximity Glare Suppression for Astronomical Coronagraphy
# subtopic name: S2.02Precision Deployable Optical Structures and Metrology
# subtopic name: S2.03 Advanced Optical Systems
# subtopic name: S4.04Extreme Environments Technology
# topic name: TA8.3 Sensor Systems
# subtopic name: A1.01Aviation External Hazard Sensor Technologies
# subtopic name: S1.01Lidar Remote Sensing Technologies
# subtopic name: S1.02Microwave Technologies for Remote Sensing
# subtopic name: S1.03Sensor and Detector Technology for Visible, IR, Far IR and Submillimeter
# subtopic name: S1.04Detector Technologies for UV, X-Ray, Gamma-Ray and Cosmic-Ray Instruments
# subtopic name: S1.05Particles and Field Sensors and Instrument Enabling Technologies
# subtopic name: S1.09Atomic Interferometry
# subtopic name: S3.04Unmanned Aircraft and Sounding Rocket Technologies
# higher level topic name: TA9 Entry, Descent and Landing Systems
# topic name: TA9.1 Aeroassist & Entry
# subtopic name: H7.01Advanced Thermal Protection Systems Technologies
# topic name: TA9.4 Vehicle Systems Technology
# subtopic name: S4.01Planetary Entry, Descent and Landing Technology
# higher level topic name: TA11 Modeling, Simulation, Information Technology and Processing
# topic name: TA11.1 Computing
# subtopic name: S5.01Technologies for Large-Scale Numerical Simulation
# topic name: TA11.2 Modeling
# subtopic name: A3.02Quiet Performance
# subtopic name: A3.05Physics-Based Conceptual Design Tools
# subtopic name: Z1.04Modeling and Measurements for Propulsion and Power
# subtopic name: S5.04Integrated Science Mission Modeling
# subtopic name: S5.05Fault Management Technologies
# topic name: TA11.4 Information Processing
# subtopic name: A1.04Prognostics and Decision Making
# subtopic name: A1.05Identification of Sequences of Atypical Occurrences in Massive Heterogeneous Datasets Representing the Operation of a System of Systems
# subtopic name: S5.02Earth Science Applied Research and Decision Support
# subtopic name: S5.03Algorithms and Tools for Science Data Processing, Discovery and Analysis, in State-of-the-Art Data Environments
# higher level topic name: TA12 Materials, Structures, Mechanical Systems and Manufacturing
# topic name: TA12.1 Materials
# subtopic name: Z2.01Cross Cutting Advanced Manufacturing Process for Large Scale Bulk Metallic Glass Systems for Aerospace Applications
# subtopic name: H5.04Hot Structures
# topic name: TA12.2 Structures
# subtopic name: A3.01Structural Efficiency-Aeroservoelasticity
# subtopic name: H5.02Deployable Structures
# subtopic name: H13.02Advanced Structural Health Monitoring
# topic name: TA12.3 Mechanical Systems
# subtopic name: A3.04Aerodynamic Efficiency
# subtopic name: A3.06Rotorcraft
# topic name: TA12.4 Manufacturing
# subtopic name: H5.01Additive Manufacturing of Lightweight Metallic Structures
# subtopic name: H10.01Recycling/Reclamation of 3-D Printer Plastic for Reuse
# topic name: TA12.5 Cross-Cutting
# subtopic name: A3.07Propulsion Efficiency - Propulsion Materials and Structures
# subtopic name: H5.03Advanced Fabrication and Manufacturing of Polymer Matrix Composite (PMC) Structures
# subtopic name: H13.01Advanced NDE Techniques for Complex Built Up Structures
# subtopic name: S2.04Optics Manufacturing and Metrology for Telescope Optical Surfaces
# higher level topic name: TA14 Thermal Management Systems
# topic name: TA14.2 Thermal Control Systems
# subtopic name: H3.01Thermal Control for Future Human Exploration Vehicles
# subtopic name: S3.07Thermal Control Systems
# higher level topic name: TA15 Aeronautics
# topic name: TA15.1 Additional Subtopics
# subtopic name: A1.02Inflight Icing Hazard Mitigation Technology
# subtopic name: A2.01Unmanned Aircraft Systems (UAS) Integration in the National Airspace System (NAS) Research
# subtopic name: A4.01Ground Test Techniques and Measurement Technologies

# %%
def handle(bs):
    totalData = []
    ### get overall topic
    regEvens = re.compile('md-taxonomy even.*')
    regOdds = re.compile('md-taxonomy odd.*')
    evens = bs.find_all("li", {"class": regEvens})
    odds = bs.find_all("li", {"class": regOdds})
    offset = 2
    for index in range(13):
        dic = {}
        higher_topic_block = evens[int(index / 2) + offset] if int(index % 2) == 0 else odds[int(index / 2) + offset]
        dic["Higher Topic"] = getHigherTopicName(higher_topic_block)
        regTopicEvens = re.compile('first-topic even.*')
        regTopicOdds = re.compile('first-topic odd.*')
        topic_even = higher_topic_block.find_all("li", {"class": regTopicEvens})
        topic_odd = higher_topic_block.find_all("li", {"class": regTopicOdds})
        for index2 in range(len(topic_even) + len(topic_odd)):
                topic_block = topic_even[int(index2 / 2)] if int(index2 % 2) == 0 else topic_odd[int(index2 / 2)]
                dic["Focus Area"] = getTopicName(topic_block)
                subtopic_even = topic_block.find_all("li", {"class": "second-topic even"})
                subtopic_odd = topic_block.find_all("li", {"class": "second-topic odd"})
                for index3 in range(len(subtopic_even) + len(subtopic_odd)):
                    subtopic_block = subtopic_even[int(index3 / 2)] if int(index3 % 2) == 0 else subtopic_odd[int(index3 / 2)]
                    dic["Subtopic"] = getSubtopicName(subtopic_block)
                    metaDic = getMetaData(subtopic_block)
                    for k in metaDic:
                        dic[k] = metaDic[k]
                    ### get other data
                    whole_info_block = subtopic_block.find("div", {"class": "whole-topic-content"})
                    new_dic = dic.copy()
                    new_dic["Content"] = filterHTMLstr(whole_info_block.get_text())
                    totalData.append(new_dic)
    return totalData

# %%
### get higher level topic
def getHigherTopicName(topic_block):
    higher_topic_name = filterHTMLstr(topic_block.find("h2").get_text())
    print("higher level topic name:", higher_topic_name)  # higher level topic name
    return higher_topic_name

### get topic name
def getTopicName(topic_block):
    topic_name = filterHTMLstr(topic_block.find("h4", {"class": "topicTitle"}).get_text())
    print("topic name:", topic_name)  # subtopic name
    return topic_name

### handle every sub-topic
def getSubtopicName(subtopic_block):
    subtopic_name = filterHTMLstr(subtopic_block.find("p", {"class": "subtopic"}).get_text())
    print("subtopic name:", subtopic_name)  # subtopic name
    return subtopic_name

# %%
### get Lead Center, Participating Center(s), Solicitation Year
def getMetaData(subtopic_block):
    dic = {}
    info_group = subtopic_block.find_all("p", {"class": "l-center"})
    for raw_info in info_group:
        info = filterHTMLstr(raw_info.get_text())
        pair = info.split(":")
        dic[pair[0]] = pair[1]
        # print(pair[0], pair[1])
    # print(dic)
    return dic

# %%
for i in evens:
    getHigherTopicName(i)
# Out:
# higher level topic name: Aeronautics Research
# higher level topic name: Science
# higher level topic name: TA1 Launch Propulsion Systems
# higher level topic name: TA3 Space Power and Energy Storage
# higher level topic name: TA5 Communication and Navigation
# higher level topic name: TA7 Human Exploration Destination Systems
# higher level topic name: TA9 Entry, Descent and Landing Systems
# higher level topic name: TA10.2 Energy Generation and Storage
# higher level topic name: TA12 Materials, Structures, Mechanical Systems and Manufacturing
# higher level topic name: TA14 Thermal Management Systems

# %%
for i in odds:
    getHigherTopicName(i)
# Out:
# higher level topic name: Human Exploration and Operations
# higher level topic name: Space Technology
# higher level topic name: TA2 In-Space Propulsion Technologies
# higher level topic name: TA4 Robotics, Telerobotics and Autonomous Systems
# higher level topic name: TA6 Human Health, Life Support and Habitation Systems
# higher level topic name: TA8 Science Instruments, Observatories & Sensor Systems
# higher level topic name: TA10 Nanotechnology
# higher level topic name: TA11 Modeling, Simulation, Information Technology and Processing
# higher level topic name: TA13 Ground and Launch Systems Processing
# higher level topic name: TA15 Aeronautics

# %%
regEvens = re.compile('md-taxonomy even.*')
regOdds = re.compile('md-taxonomy odd.*')
evens = bs.find_all("li", {"class": regEvens})
odds = bs.find_all("li", {"class": regOdds})
offset = 2
for index in range(16):
    higher_topic_block = evens[int(index / 2) + offset] if int(index % 2) == 0 else odds[int(index / 2) + offset]
    getHigherTopicName(higher_topic_block)
    regTopicEvens = re.compile('first-topic even.*')
    regTopicOdds = re.compile('first-topic odd.*')
    topic_even = higher_topic_block.find_all("li", {"class": regTopicEvens})
    topic_odd = higher_topic_block.find_all("li", {"class": regTopicOdds})
    for index2 in range(len(topic_even) + len(topic_odd)):
            topic_block = topic_even[int(index2 / 2)] if int(index2 % 2) == 0 else topic_odd[int(index2 / 2)]
            getTopicName(topic_block)
            subtopic_even = topic_block.find_all("li", {"class": "second-topic even"})
            subtopic_odd = topic_block.find_all("li", {"class": "second-topic odd"})
            for index3 in range(len(subtopic_even) + len(subtopic_odd)):
                subtopic_block = subtopic_even[int(index3 / 2)] if int(index3 % 2) == 0 else subtopic_odd[int(index3 / 2)]
                getSubtopicName(subtopic_block)
# Out:
# higher level topic name: TA1 Launch Propulsion Systems
# topic name: TA1.2 Liquid Rocket Propulsion Systems
# subtopic name: H10.01Cryogenic Purge Gas Recovery and Reclamation
# higher level topic name: TA2 In-Space Propulsion Technologies
# topic name: TA2.1 Chemical Propulsion
# subtopic name: H2.01In-Space Chemical Propulsion
# subtopic name: S4.03Spacecraft Technology for Sample Return Missions
# topic name: TA2.2 Non-Chemical Propulsion
# subtopic name: H2.02Nuclear Thermal Propulsion (NTP)
# subtopic name: H2.03High Power Electric Propulsion
# subtopic name: S3.02Propulsion Systems for Robotic Science Missions
# topic name: TA2.4 Supporting Technologies
# subtopic name: H2.04Cryogenic Fluid Management for In-Space Transportation
# higher level topic name: TA3 Space Power and Energy Storage
# topic name: TA3.1 Power Generation
# subtopic name: H8.01Space Nuclear Power Systems
# subtopic name: H8.02Solid Oxide Fuel Cells and Electrolyzers
# subtopic name: H8.03Advanced Photovoltaic Systems
# subtopic name: S3.01Power Generation and Conversion
# subtopic name: Z4.01Small Spacecraft in Deep Space: Power, Navigation, and Structures
# topic name: TA3.4 Cross Cutting Technology
# subtopic name: S3.03Power Electronics and Management, and Energy Storage
# subtopic name: Z1.02Solid-State Thermal-to-Electric Power Generation
# higher level topic name: TA4 Robotics, Telerobotics and Autonomous Systems
# topic name: TA4.1 Sensing & Perception
# subtopic name: Z5.01Payload Technologies for Assistive Free-Flyers
# topic name: TA4.3 Manipulation
# subtopic name: S4.02Robotic Mobility, Manipulation and Sampling
# topic name: TA4.4 Human-Systems Integration
# subtopic name: H6.01Human Robotic Systems - Mobility Subsystem, Manipulation Subsystem, and Human System Interaction
# topic name: TA4.5 Autonomy
# subtopic name: A2.02Unmanned Aircraft Systems Technology
# subtopic name: S5.05Fault Management Technologies
# topic name: TA4.7 RTA Systems Engineering
# subtopic name: S4.05Contamination Control and Planetary Protection
# higher level topic name: TA5 Communication and Navigation
# topic name: TA5.1 Optical Comm. And Navigation
# subtopic name: H9.01Long Range Optical Telecommunications
# subtopic name: H9.03Flight Dynamics and Navigation Technology
# subtopic name: S3.08Slow and Fast Light
# topic name: TA5.4 Position, Navigation, and Timing
# subtopic name: S3.05Guidance, Navigation and Control
# topic name: TA5.5 Integrated Technologies
# subtopic name: H9.02Intelligent Communication Systems
# higher level topic name: TA6 Human Health, Life Support and Habitation Systems
# topic name: TA6.1 Environmental Control Life Support & Habitation Systems
# subtopic name: H14.02International Space Station (ISS) Demonstration of Improved Exploration Technologies
# subtopic name: H3.01Environmental Monitoring for Spacecraft Cabins
# subtopic name: H3.02Bioregenerative Technologies for Life Support
# subtopic name: H3.03Spacecraft Cabin Atmosphere Quality and Thermal Management
# topic name: TA6.2 Extravehicular Activity Systems
# subtopic name: H4.01Crew Survival Systems for Launch, Entry, Abort
# subtopic name: H4.02EVA Space Suit Pressure Garment Systems
# subtopic name: H4.03EVA Space Suit Power, Avionics, and Software Systems
# topic name: TA6.3 Human Health and Performance
# subtopic name: H12.01Measurements of Net Ocular Blood Flow
# subtopic name: H12.02Unobtrusive Workload Measurement
# subtopic name: H12.03Technology for Monitoring Muscle Protein Synthesis and Breakdown in Spaceflight
# topic name: TA6.5 Radiation
# subtopic name: H11.01Radiation Shielding Technologies
# higher level topic name: TA7 Human Exploration Destination Systems
# topic name: TA7.1 In-Situ Resource Utilization
# subtopic name: H1.01Regolith ISRU for Mission Consumable Production
# subtopic name: H14.01International Space Station (ISS) Utilization
# topic name: TA7.2 Sustainability & Supportability
# subtopic name: H14.03Recycling/Reclamation of 3-D Printer Plastic Including Transformation of Launch Package Solutions into 3-D Printed Parts
# higher level topic name: TA8 Science Instruments, Observatories & Sensor Systems
# topic name: TA8.1 Science Instruments
# subtopic name: S1.03Sensor and Detector Technology for Visible, IR, Far IR and Submillimeter
# subtopic name: S1.04Detector Technologies for UV, X-Ray, Gamma-Ray and Cosmic-Ray Instruments
# subtopic name: S1.05Particles and Field Sensors and Instrument Enabling Technologies
# subtopic name: S1.06In Situ Sensors and Sensor Systems for Lunar and Planetary Science
# subtopic name: S1.07Airborne Measurement Systems
# subtopic name: S1.08Surface & Sub-surface Measurement Systems
# subtopic name: S2.01Proximity Glare Suppression for Astronomical Coronagraphy
# subtopic name: S2.03Advanced Optical Systems and Fabrication/Testing/Control Technologies for EUV/Optical and IR Telescope
# subtopic name: S3.09Command, Data Handling, and Electronics
# topic name: TA8.2 Observations
# subtopic name: S2.02Precision Deployable Optical Structures and Metrology
# subtopic name: S2.04X-Ray Mirror Systems Technology, Coating Technology for X-Ray-UV-OIR, and Free-Form Optics
# subtopic name: S3.04Unmanned Aircraft and Sounding Rocket Technologies
# topic name: TA8.3 Sensor Systems
# subtopic name: H14.04Optical Components, Sensors, and Systems for ISS Utilization
# subtopic name: S1.01Lidar Remote Sensing Technologies
# subtopic name: S1.02Microwave Technologies for Remote Sensing
# subtopic name: S1.09Atomic Interferometry
# subtopic name: S1.10Cryogenic Systems for Sensors and Detectors
# higher level topic name: TA9 Entry, Descent and Landing Systems
# topic name: TA9.1 Aeroassist & Entry
# subtopic name: H7.01Ablative Thermal Protection Systems Technologies, Sensors and NDE Methods
# subtopic name: H7.02Diagnostic Tools for High Velocity Testing and Analysis
# topic name: TA9.2 Descent
# subtopic name: Z3.01Wireless Cameras for Entry, Descent, and Landing Reconstruction
# topic name: TA9.4 Vehicle Systems Technology
# subtopic name: S4.01Planetary Entry, Descent and Landing and Small Body Proximity Operation Technology
# higher level topic name: TA10 Nanotechnology
# topic name: TA10.1 Engineered Materials and Structures
# subtopic name: A1.01Structural Efficiency-Hybrid Nanocomposites
# higher level topic name: TA10.2 Energy Generation and Storage
# topic name: TA10.2.1 Energy Storage
# subtopic name: S3.06Terrestrial and Planetary Balloons
# higher level topic name: TA11 Modeling, Simulation, Information Technology and Processing
# topic name: TA11.1 Computing
# subtopic name: S5.01Technologies for Large-Scale Numerical Simulation
# topic name: TA11.2 Modeling
# subtopic name: A1.04Quiet Performance
# subtopic name: A1.05Physics-Based Conceptual Aeronautics Design Tools
# subtopic name: A1.07Efficient Propulsion and Power
# subtopic name: S5.04Integrated Science Mission Modeling
# subtopic name: Z1.01Modeling and Measurements for Propulsion and Power
# topic name: TA11.4 Information Processing
# subtopic name: S5.02Earth Science Applied Research and Decision Support
# subtopic name: S5.03Algorithms and Tools for Science Data Processing, Discovery and Analysis, in State-of-the-Art Data Environments
# higher level topic name: TA12 Materials, Structures, Mechanical Systems and Manufacturing
# topic name: TA12.1 Materials
# subtopic name: H5.02Extreme Temperature Structures
# subtopic name: S4.04Extreme Environments Technology
# subtopic name: Z2.01Large-Scale Polymer Matrix Composite (PMC) Structures, Materials, and Manufacturing Processes
# topic name: TA12.2 Structures
# subtopic name: H5.01Deployable Structures
# subtopic name: H5.03Multifunctional Materials and Structures
# topic name: TA12.3 Mechanical Systems
# subtopic name: A1.06Vertical Lift
# subtopic name: H13.01Advanced NDE Modeling and Analysis
# topic name: TA12.5 Cross-Cutting
# subtopic name: A1.03Low Emissions Propulsion and Power
# subtopic name: H13.02NDE Sensors
# subtopic name: Z6.01Advanced Metallic Materials and Processes Innovation
# higher level topic name: TA13 Ground and Launch Systems Processing
# topic name: TA13.3 Technologies to Increase Reliability and Mission Availability
# subtopic name: A2.01Flight Test and Measurements Technologies
# higher level topic name: TA14 Thermal Management Systems
# topic name: TA14.2 Thermal Control Systems
# subtopic name: S3.07Thermal Control Systems
# higher level topic name: TA15 Aeronautics
# topic name: TA15.1 Additional Subtopics
# subtopic name: A1.02Aerodynamic Efficiency Drag Reduction Technology
# subtopic name: A1.08Ground Testing and Measurement Technologies
# subtopic name: A3.01Advanced Air Traffic Management Systems Concepts
# subtopic name: A3.02Autonomy of the National Airspace System (NAS)
# subtopic name: A3.03Future Aviation Systems Safety
